# %%
import pandas as pd
import numpy as np

# %%
tweet = pd.read_csv('./elonmusk_tweets.csv')

# %%
tweet.head(20)
# Out:
#                     id           created_at  \
# 0   849636868052275200  2017-04-05 14:56:29
# 1   848988730585096192  2017-04-03 20:01:01
# 2   848943072423497728  2017-04-03 16:59:35
# 3   848935705057280001  2017-04-03 16:30:19
# 4   848416049573658624  2017-04-02 06:05:23
# 5   848415731502923777  2017-04-02 06:04:07
# 6   848415356263702528  2017-04-02 06:02:38
# 7   848398971139629057  2017-04-02 04:57:31
# 8   848244577521647616  2017-04-01 18:44:01
# 9   848243350993895424  2017-04-01 18:39:09
# 10  848239928043491328  2017-04-01 18:25:33
# 11  848239664536223745  2017-04-01 18:24:30
# 12  848036043240636417  2017-04-01 04:55:23
# 13  847958571895619584  2017-03-31 23:47:32
# 14  847890916048338946  2017-03-31 19:18:42
# 15  847884776719740928  2017-03-31 18:54:18
# 16  847884413706874880  2017-03-31 18:52:51
# 17  847884351375372288  2017-03-31 18:52:36
# 18  847883435100299267  2017-03-31 18:48:58
# 19  847882909906341888  2017-03-31 18:46:53
#
#                                                  text
# 0   b'And so the robots spared humanity ... https:...
# 1   b"@ForIn2020 @waltmossberg @mims @defcon_5 Exa...
# 2       b'@waltmossberg @mims @defcon_5 Et tu, Walt?'
# 3                 b'Stormy weather in Shortville ...'
# 4   b"@DaveLeeBBC @verge Coal is dying due to nat ...
# 5   b"@Lexxxzis It's just a helicopter in helicopt...
# 6                           b"@verge It won't matter"
# 7                       b'@SuperCoolCube Pretty good'
# 8   b"Why did we waste so much time developing sil...
# 9   b'Technology breakthrough: turns out chemtrail...
# 10  b"RT @OpenAI: We've created the world's first ...
# 11  b'RT @ProfBrianCox: This is extremely importan...
# 12  b'@adamsbj Def P100D with Ludicrous+, although...
# 13  b'@BadAstronomer We can def bring it back like...
# 14        b'@tesla_addict @TeslaMotors Working on it'
# 15  b"@jasonlamb Looks like it could do 20% more w...
# 16                                   b'@cheron A lot'
# 17  b'@Cardoso Silliest thing we can imagine! Secr...
# 18  b'@redletterdave Good point, odds go from 0% t...
# 19  b'Falcon Heavy test flight currently scheduled...

# %%
tweet = tweet[['created_at', 'text']]

# %%
tweet['created_at']= pd.to_datetime(tweet.created_at)

# %%
tweet.head()
# Out:
#            created_at                                               text
# 0 2017-04-05 14:56:29  b'And so the robots spared humanity ... https:...
# 1 2017-04-03 20:01:01  b"@ForIn2020 @waltmossberg @mims @defcon_5 Exa...
# 2 2017-04-03 16:59:35      b'@waltmossberg @mims @defcon_5 Et tu, Walt?'
# 3 2017-04-03 16:30:19                b'Stormy weather in Shortville ...'
# 4 2017-04-02 06:05:23  b"@DaveLeeBBC @verge Coal is dying due to nat ...

# %%
tweet.dtypes
# Out:
# created_at    datetime64[ns]
# text                  object
# dtype: object

# %%
tweet.tail()
# Out:
#               created_at                                               text
# 2814 2011-12-03 08:22:07               b'That was a total non sequitur btw'
# 2815 2011-12-03 08:20:28  b'Great Voltaire quote, arguably better than T...
# 2816 2011-12-01 10:29:04  b'I made the volume on the Model S http://t.co...
# 2817 2011-12-01 09:55:11  b"Went to Iceland on Sat to ride bumper cars o...
# 2818 2010-06-04 18:31:57  b'Please ignore prior tweets, as that was some...

# %% [markdown]
# # Webscraping part

# %%
import bs4
from bs4 import BeautifulSoup
import urllib
from urllib import urlopen
import requests
import time
import pandas as pd

# %% [markdown]
# ## Tesla Blog

# %%
URL = "https://www.tesla.com/blog"

# %%
html = urllib.urlopen(URL).read()

soup = BeautifulSoup(html, 'html.parser', from_encoding="utf-8")

# %%
dataframe = pd.DataFrame(columns=["title","date","first_paragraph"])

# %%
### trying to get this to work, currently not. need to troubleshoot
def scrap():
    for row in soup.find_all('div', {'class':'view-content'}):
        classes= row.find_all('div', {'class':'blog-wrapper no-image'})
        for entry in classes:
            title = entry.find('h2').get_text()
            date = entry.find('span', attrs= {"property":"dc:date dc:created"}).get_text()
            first_paragraph = entry.find('div', attrs= {"class": "field-item even"}).get_text()
            dataframe.loc[len(dataframe)]=[title.strip(), date.strip(), first_paragraph.strip()]

# %%
scrap()

# %%
dataframe
# Out:
#                                                title               date  \
# 0  Tesla Welcomes Linda Johnson Rice and James Mu...      July 17, 2017
# 1  Tesla Powerpack to Enable Large Scale Sustaina...       July 6, 2017
# 2  Tesla Model X the First SUV Ever to Achieve 5-...      June 13, 2017
# 3                       Tesla Welcomes Gaby Toledano       May 23, 2017
# 4       Creating the Safest Car Factory in the World       May 14, 2017
# 5       The Next Step in Energy Storage: Aggregation       May 12, 2017
# 6                                         Solar Roof       May 10, 2017
# 7                           Charging Is Our Priority     April 24, 2017
# 8                                 Model S or Model 3      April 6, 2017
# 9  CFO Jason Wheeler to Depart in April to Pursue...  February 22, 2017
#
#                                      first_paragraph
# 0  We would like to welcome Linda Johnson Rice, C...
# 1  Last September, a 50-year storm damaged critic...
# 2  We engineered Model X to be the safest SUV eve...
# 3  We would like to welcome Gaby Toledano, who ha...
# 4  Earlier this year, the United Automobile Worke...
# 5  Today, modern utilities and grid operators are...
# 6  Tesla’s mission is to accelerate the world’s t...
# 7  As Tesla prepares for our first mass-market ve...
# 8  We’ve been getting ready for Model 3 by advanc...
# 9  Tesla today announced that CFO Jason Wheeler h...

# %%
#creating a template for multiple pages of blog
url_template = "http://www.tesla.com/blog?page={}"
results = []
for start in range(1,50):
    url_template = "http://www.tesla.com/blog?page={}".format(start)
    results.append(url_template)

# %%
#placing those results into a dataframe by running the scraper again
for i in results:
    r = requests.get(i)
    soup = BeautifulSoup(r.text,"html.parser")
    scrap()

# %%
dataframe
# Out:
#                                                  title                date  \
# 0    Tesla Welcomes Linda Johnson Rice and James Mu...       July 17, 2017
# 1    Tesla Powerpack to Enable Large Scale Sustaina...        July 6, 2017
# 2    Tesla Model X the First SUV Ever to Achieve 5-...       June 13, 2017
# 3                         Tesla Welcomes Gaby Toledano        May 23, 2017
# 4         Creating the Safest Car Factory in the World        May 14, 2017
# 444  The Secret Tesla Motors Master Plan (just betw...      August 2, 2006
# 445                                     Lotus Position       July 25, 2006
# 446                                           Attitude       July 19, 2006
#
#                                        first_paragraph
# 0    We would like to welcome Linda Johnson Rice, C...
# 1    Last September, a 50-year storm damaged critic...
# 2    We engineered Model X to be the safest SUV eve...
# 3    We would like to welcome Gaby Toledano, who ha...
# 4    Earlier this year, the United Automobile Worke...
# 5    Today, modern utilities and grid operators are...
# 6    Tesla’s mission is to accelerate the world’s t...
# 7    As Tesla prepares for our first mass-market ve...
# 8    We’ve been getting ready for Model 3 by advanc...
# 9    Tesla today announced that CFO Jason Wheeler h...
# 10   At Tesla, the safety of our customers comes fi...
# 11   Tesla created the Supercharger network to make...
# 12   We would like to welcome Chris Lattner, who wi...
# 13   Tesla’s mission is to accelerate the world’s t...
# 14   Tesla and Panasonic have finalized an agreemen...
# 15   We designed the Supercharger network to enable...
# 16   Tesla’s shareholders have overwhelmingly appro...
# 17   In response to Germany’s Kraftfahrt-Bundesamt ...
# 18   Today, we are truly honored to announce that M...
# 19   Accelerating a sustainable energy future is on...
# 20   Four years ago, Tesla introduced the Superchar...
# 21   We very much appreciate that Institutional Sha...
# 22   Our Mission, Our Vision, and Our Products This...
# 23   Ahead of tomorrow’s solar roof and Powerwall a...
# 24   Self-driving vehicles will play a crucial role...
# 25   Tesla and Panasonic have entered into a non-bi...
# 26   Today, Tesla and SolarCity took another signif...
# 27   Last October, a catastrophic rupture in the Al...
# 28   While there are dozens of small refinements wi...
# 29   The Model S P100D with Ludicrous mode is the t...
# ..                                                 ...
# 417  Stephen Casner spent 25 years working on proto...
# 418  We've just achieved a significant milestone on...
# 419  Jon Mittelhauser is one of the early developer...
# 420  From the earliest days of our work developing ...
# 421  Dr. Rob Wilder is CEO of WilderShares LLC and ...
# 422  Let me start off by apologizing to Dr. Robert ...
# 423  You’ve probably noticed that I’ve been away fr...
# 424  Wally Rippel is a long-time proponent of elect...
# 425  Jon Faiz Kayyem, PhD, is a Managing Partner of...
# 426  Editor's note: Our last blog, Good Vibrations,...
# 427  Imagine yourself strapped into a Tesla Roadste...
# 428  Tesla Motors wasn't planning to attend an auto...
# 429  By now most people know that the Tesla Roadste...
# 430  At its heart, Tesla Motors is an engineering c...
# 431  Don Cox is a Professor of Electrical Engineeri...
# 432  How fast is it? That’s a common question we ge...
# 433  Bob Bressler is a customer of Tesla Motors and...
# 434  I’m taking a break from answering questions to...
# 435  A bit about motors, magnets, AC and DC, and we...
# 436  Elon and Martin both recognize the synergy bet...
# 437  This blog continues to attract some fascinatin...
# 438  Many of you have asked me about hybrid technol...
# 439  Many of you have asked me about several altern...
# 440  Editor's Note: As our Blog has taken off in po...
# 441  I know, I know. There are at least a dozen goo...
# 442  Not too long from now, most cars will be elect...
# 443  I continue to be blown away by the number and ...
# 444  Background: My day job is running a space tran...
# 445  Holy smokes! There is no way I can respond to ...
# 446  Welcome to the inaugural edition of the Tesla ...
#
# [447 rows x 3 columns]
